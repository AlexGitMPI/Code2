# %% [markdown]
# # ReWoCap Data renaming

# %%
import os 
import shutil
import IPython
from IPython import embed
from os import path

#The program will create new, correctly named folders at the desired location and then copy and rename the files from Jeti, Westboro, Klein, GoPro and Depthcamer into these folders

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
###################################################################
####### Please make sure, the following requirements are met ######
###################################################################
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#
# - All files are in the same folder without any subfolders in it
# - Jeti-files are named jetitime (e.g. jeti0800, jeti0930, jeti1330)
# - Westboro-files are named wptime (e.g. wp0800, wp0930, wp1330)
# - Klein-files are named kleintime (e.g. klein0800, klein0930, klein1330)
# - Jeti-files are named jetitime (e.g. jeti0800, jeti0930, jeti1330)
# - The GoPro- and Depthcamera-files have an automatically created name, which should not be changes manually! Simply copy the files into the folder to all the other files
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
###################################################################
###################################################################
###################################################################
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #


# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
###################################################################
########## CHECK & CORRECT THE FOLLOWING VARIABLES ##########
###################################################################
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

#To name the folders correctly, the information about the date and the time of the first measurement is given in the following order
##### "ID_yearmonthday" --> e.g. "1010_20230429"
ID_date = "1010_20230429"

#####Please CHANGE THE PATH to where the new folders should to be created. Usually this does not need to be changed since the information is already given by "ID_date"
path = "/Users/alex/rewocap2/data/raw/" + ID_date

#####Please CHANGE THE PATH OF THE SOURCE where the program gets the originally saved files from
source_path = path + "/filler/"

#To inform the program about the number of measurements, please fill in the time of the first and last measurement (first_m & last_m)
##### Change the time of first measurement (e.g. 730, 900, 1130)
first_m = 730

##### Change the time of last measurement
last_m = 1400

#goprophoto_first is the number given to the GoPro-JPG of our first measurement in its dataname
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
##### Change the first GoproPhoto number
goprophoto_first = 284

#goprophoto_first is the number given to the GoPro-MP4 of our first measurement in its dataname
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
##### Change the first GoproVideo number
goprovideo_first = 285

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
#############################################################
#############################################################
#############################################################
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #





os.chdir(path) 
print("The program will take files from the path " + source_path)
print("The program will create folders with new and renamed files in " + path)

#The program assumes two measurements per hour and therefore adds two measurements to the list "liste[]"
#The lenght of the list is equal to the amount of measurements taken on that day, an information needed for the for-loops
times_m = []
#first_m1 is used in functions instead of first_m
first_m1 = first_m
times_m.append(str(first_m1))
#this loop creates a list with all measurement-time of day, as it relies on a 30 minute measurement intervall
#the lenght of the list is used in the for-loops
while first_m1 < last_m:
    if "3" in str(first_m1) and not "300" in str(first_m1):
        first_m1 = first_m1 + 70
        times_m.append(str(first_m1))
    else:
        first_m1 = first_m1 + 30
        times_m.append(str(first_m1))
print("According to you entry of measurement times, you performed " + str(len(times_m)) + " measurements")


count = 0
#now all the folders with the correct ID, date and time will be created
def foldercreation():
    localfirst_m = first_m
    for count in range(0, len(times_m)):
        if count <= len(times_m):
            count = count + 1
            if localfirst_m < 1000:
                os.mkdir(ID_date + "T0" + str(localfirst_m))
                if "3" in str(localfirst_m):
                    localfirst_m = localfirst_m +70
                else:
                    localfirst_m = localfirst_m +30
            else: 
                os.mkdir(ID_date + "T" + str(localfirst_m))
                #if first_m is at time at half past smth., it has to add 70 to equal a full hour. Else it has to add 30 (min).
                #"and not" 300 is necessary to prevent confusion when the programm arrives at 1300
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    localfirst_m = localfirst_m + 70
                else:
                    localfirst_m = localfirst_m + 30
        else:
            break
foldercreation()




#Now follows the change in directory to each of the newly created folders
#####Please add the TIME OF THE FIRST-MEASUREMENT as "first_m"


#copying the wp.csv files to the newly created folders
#Some variables that help finding the right directory-names and to create sources and targets
IDdateT0 = ID_date + "T0"
IDdateT = ID_date + "T"

def file_copy_standart():
    addition = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1 
            # The addition increases the value of the measurement time to ensure correct naming
            localfirst_m = first_m + addition
            if os.path.exists(ID_date + "T0" + str(localfirst_m)) == True:
                source = source_path + data_begin1 + str(localfirst_m) + data_surfix
                if localfirst_m < 1000:
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                       # localfirst_m = localfirst_m + 70
                        addition =  addition + 70
                    else:
                      #  localfirst_m = localfirst_m + 30
                        addition = addition + 30
                else:
                    target =   path + ID_date + "T" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                    else:
                        addition = addition + 30
                shutil.copy2(source, target) 
            #This elif is necessary to copy files-measurements that were done after 09:59
            elif os.path.exists(ID_date + "T" + str(localfirst_m)) == True:
                source = source_path + data_begin2 + str(localfirst_m) + data_surfix
                if localfirst_m < 1000:
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    shutil.copy2(source, target)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                    else:
                        addition = addition + 30
                else:
                    target =   path + "/" + ID_date + "T" + str(localfirst_m)
                    shutil.copy2(source, target)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                    else:
                        addition = addition + 30 
        else:
            break

#wp690csv.files will be copied
data_begin1 = "wp0"
data_begin2 = "wp"
data_surfix =".csv"
file_copy_standart()

#wp.690.pmm files will be copied
data_begin1 = "wp0"
data_begin2 = "wp"
data_surfix =".pmm"
file_copy_standart()  

#jeti.xlsx.files will be copied
data_begin1 = "klein0"
data_begin2 = "klein"
data_surfix =".csv"
file_copy_standart()    

#jeti.xlsx.files will be copied
data_begin1 = "jeti0"
data_begin2 = "jeti"
data_surfix =".xlsx"
file_copy_standart()  

#The GoPro- and Depth-camera-files are created automatically and their different naming needs to be referenced in a adapted file_copy function
def file_copy_goprophoto():
    addition = 0
    addition_gp = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            localgopro_first = goprophoto_first + addition_gp
            if os.path.exists(ID_date + "T0" + str(localfirst_m)) == True or os.path.exists(ID_date + "T" + str(localfirst_m)) == True:
                source = source_path + data_begin1 + str(localgopro_first) + data_surfix
                if localfirst_m < 1000:
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                        addition_gp = addition_gp + 2
                    else:
                        addition = addition + 30
                        addition_gp = addition_gp + 2
                else:
                    target =   path + "/" + ID_date + "T" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                        addition_gp = addition_gp + 2
                    else:
                        addition = addition + 30
                        addition_gp = addition_gp + 2
                shutil.copy2(source, target)
            else:
                break 
        else:
            break

#The GoPro- and Depth-camera-files are created automatically and their different naming needs to be referenced in a adapted file_copy function
def file_copy_goprovideo():
    addition = 0
    addition_gp = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            localgopro_first = goprovideo_first + addition_gp
            if os.path.exists(ID_date + "T0" + str(localfirst_m)) == True or os.path.exists(ID_date + "T" + str(localfirst_m)) == True:
                source = source_path + data_begin1 + str(localgopro_first) + data_surfix
                if localfirst_m < 1000:
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                        addition_gp = addition_gp + 2
                    else:
                        addition = addition + 30
                        addition_gp = addition_gp + 2
                else:
                    target =   path + "/" + ID_date + "T" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                        addition_gp = addition_gp + 2
                    else:
                        addition = addition + 30
                        addition_gp = addition_gp + 2
                shutil.copy2(source, target)
            else:
                break
        else:
            break

            
            
#gopro.GPR.files will be copied
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
data_begin1 = "GOPR0"
data_surfix =".GPR"
file_copy_goprophoto() 

#gopro.JPG.files will be copied
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
data_begin1 = "GOPR0"
data_surfix =".JPG"
file_copy_goprophoto()

#gopro.MP4.files will be copied
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
#first_m = 730
data_begin1 = "GX010"
data_surfix =".MP4"
file_copy_goprovideo()

#The GoPro- and Depth-camera-files are created automatically and their different naming needs to be referenced in a adapted file_copy function
#After performing the measurement, it is required to edit the name of the bag.-files manually by giving them the time that the measurment was executed at. 20230429_073243 --> 20230429_0730
def file_copy_depth():
    addition = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            if os.path.exists(ID_date + "T0" + str(localfirst_m)) == True:
                if localfirst_m < 1000:
                    source = source_path + data_begin + "_0" + str(localfirst_m) + data_surfix
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                        
                    else:
                        addition = addition + 30
                        
                else:
                    source = source_path + data_begin + "_" + str(localfirst_m) + data_surfix
                    target =   path + "/" + ID_date + "T" + str(localfirst_m)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70
                    else:
                        addition = addition + 30
                shutil.copy2(source, target)
            #This elif is necessary to copy files-measurements that were done after 09:59
            elif os.path.exists(ID_date + "T" + str(localfirst_m)) == True:
                source = source_path + data_begin + "_" + str(localfirst_m) + data_surfix
                if localfirst_m < 1000:
                    target = path + "/" + ID_date + "T0" + str(localfirst_m)
                    shutil.copy2(source, target)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70                       
                    else:
                        addition = addition + 30                     
                else:
                    target =  path + "/" + ID_date + "T" + str(localfirst_m)
                    shutil.copy2(source, target)
                    if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                        addition = addition + 70                
                    else:
                        addition = addition + 30 
        else:
            break

#BAG.files will be copied
#the first measurement of the gopro is represented by an interally created number that the system gives to the file. Every subsequent measurement with the same file-ending will be added 2 to the previous measurement-title
data_begin = ID_date[5:13]
data_surfix =".bag"
file_copy_depth()

#Now follows the renaming of all files
# --> Depth-camera .bag-files
def data_renaming_depth():
    addition = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            if localfirst_m < 1000:
                os.chdir(path + "/" + ID_date + "T0" + str(localfirst_m))
                os.rename(data_begin + "_0" + str(localfirst_m) + data_surfix, data_begin1 + data_begin + "T0" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                else:
                    addition = addition + 30
            else:                
                os.chdir(path + "/" + ID_date + "T" + str(localfirst_m))
                os.rename(data_begin + "_" + str(localfirst_m) + data_surfix, data_begin1 + data_begin + "T" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                else:
                    addition = addition + 30               
        else: 
            break

# --> Depth-camera .bag-files
data_begin1 = "inteld455_"
data_surfix =".bag"
data_renaming_depth()

# --> GoPro files renaming
def data_renaming_gopro1():
    addition = 0
    addition_gp = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            localgopro_first = goprophoto_first + addition_gp
            if localfirst_m < 1000:
                os.chdir(path + "/" + ID_date + "T0" + str(localfirst_m))
                os.rename(data_begin1 + str(localgopro_first) + data_surfix, data_begin3 + data_begin + "T0" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                    addition_gp = addition_gp + 2
                else:
                    addition = addition + 30
                    addition_gp = addition_gp + 2
            else:
                os.chdir(path + "/" + ID_date + "T" + str(localfirst_m))
                os.rename(data_begin1 + str(localgopro_first) + data_surfix, data_begin3 + data_begin + "T" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                    addition_gp = addition_gp + 2
                else:
                    addition = addition + 30
                    addition_gp = addition_gp + 2  
        else: 
            break

# --> GoPro .GPR-files
data_begin1 = "GOPR0"
data_begin3 = "gopro10photo_"
data_surfix =".GPR"
data_renaming_gopro1()

# --> GoPro .JPG-files
data_begin1 = "GOPR0"
data_begin3 = "gopro10photo_"
data_surfix =".JPG"
data_renaming_gopro1()

#Small changes for the .MP4
def data_renaming_gopro2():
    addition = 0
    addition_gp = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            localgopro_first = goprovideo_first + addition_gp
            if localfirst_m < 1000:
                os.chdir(path + "/" + ID_date + "T0" + str(localfirst_m))
                os.rename(data_begin1 + str(localgopro_first) + data_surfix, data_begin3 + data_begin + "T0" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                    addition_gp = addition_gp + 2
                else:
                    addition = addition + 30
                    addition_gp = addition_gp + 2
            else:          
                os.chdir(path + "/" + ID_date + "T" + str(localfirst_m))
                os.rename(data_begin1 + str(localgopro_first) + data_surfix, data_begin3 + data_begin + "T" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                    addition_gp = addition_gp + 2
                else:
                    addition = addition + 30
                    addition_gp = addition_gp + 2               
        else: 
            break

# --> GoPro .MP4-files
data_begin1 = "GX010"
data_begin2 = ID_date[5:13] 
data_begin3 = "gopro10video_"
Add_ = "_"
AddT0 = "T0"
data_surfix =".MP4"
data_renaming_gopro2()

#Renaming of the Jeti, Klein and Westoboro (JKW)-files
def data_renaming_JKW():
    addition = 0
    addition_gp = 0
    for count in range(0,len(times_m)):
        if count <= len(times_m):
            count = count + 1
            localfirst_m = first_m + addition
            if localfirst_m < 1000:
                os.chdir(path + "/" + ID_date + "T0" + str(localfirst_m))
                os.rename(data_begin1 + "0" + str(localfirst_m) + data_surfix, data_begin3 + data_begin + "T0" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                else:
                    addition = addition + 30              
            else:
                os.chdir(path + "/" + ID_date + "T" + str(localfirst_m))
                os.rename(data_begin1 + str(localfirst_m) + data_surfix, data_begin3 + data_begin + "T" + str(localfirst_m) + data_surfix)
                if "3" in str(localfirst_m) and not "300" in str(localfirst_m):
                    addition = addition + 70
                else:
                    addition = addition + 30   
        else: 
            break
            
#Jeti.xlsx-files
data_begin1 = "jeti"
data_begin2 = ID_date[5:13] 
data_begin3 = "jeti1511_"
Add_ = "_"
AddT0 = "T0"
data_surfix =".xlsx"
data_renaming_JKW()

#Klein.csv-files
data_begin1 = "klein"
data_begin2 = ID_date[5:13] 
data_begin3 = "kleink10a_"
Add_ = "_"
AddT0 = "T0"
data_surfix =".csv"
data_renaming_JKW()

#Westboro.csv-files
data_begin1 = "wp"
data_begin2 = ID_date[5:13] 
data_begin3 = "wp690_"
Add_ = "_"
AddT0 = "T0"
data_surfix =".csv"
data_renaming_JKW()

#Westboro.pmm-files
data_begin1 = "wp"
data_begin2 = ID_date[5:13] 
data_begin3 = "wp690_"
Add_ = "_"
AddT0 = "T0"
data_surfix =".pmm"
data_renaming_JKW()

print("Done")
exit()
# Out:
# The program will take files from the path /Users/alex/rewocap2/data/raw/1010_20230429/filler/
# The program will create folders with new and renamed files in /Users/alex/rewocap2/data/raw/1010_20230429
# According to you entry of measurement times, you performed 14 measurements
# Done
